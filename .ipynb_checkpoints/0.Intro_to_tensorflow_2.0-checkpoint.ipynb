# %% [markdown]
# ### Conda info
#
# Per vedere tutti gli ambienti presenti:
#
#         conda info --envs
#         # l'env attivo è quello con "*"
#
# L'env attivo indica l'ambiente che usa `jupyter` (e di conseguenza i pacchetti che ha a disposizione)

# %%
conda info --envs
# Out:
# # conda environments:
# #
# base                     /opt/anaconda3
# ai                    *  /opt/anaconda3/envs/ai
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##### Per avviare un notebook che deve usare uno specifico ambiente abbiamo due possibilità:
#
# 1. Facendo `conda activate base` e poi facendo `jupyter notebook` aprimo l'ambiente di default (base) e andando su `kernel -> change kernel` possiamo scegliere tra i diversi ambiente che abbiamo a disposizione
#
# 1. In alternativa possiamo fare direttmente `conda activate ai` (ovvero attiviamo l'ambiente a cui siamo interessati) e poi facciamo `jupyter notebook` direttamente da li. In questo modo su `kernel -> change kernel` non vedremo altre opzioni possibili e l'ambiente che stiamo utilizzando è direttamente quello attivato, quindi in questo caso `ai`

# %% [markdown]
# ###### Per installare tensorflow su uno specifico ambiente dobbiamo:
#
# 1. Come prima cosa attiviamo l'ambiente: `conda activate ai`
#
# 1. Poi facciamo:
#         pip install tensorflow==2.1.0
#    oppure
#         conda install tensorflow==2.1.0
#
# 1. Per verificare se l'installazione è corretta:
#
#         conda list tensorflow

# %% [markdown]
# ##### Se aggiungiamo nuovi pacchetti

# %%
import sys
print(sys.prefix)
print(sys.version)
# Out:
# /opt/anaconda3/envs/ai
# 3.6.10 |Anaconda, Inc.| (default, Jan  7 2020, 15:01:53)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]

# %% [markdown]
# ### First Notebook using Fashion-MNIST

# %%
import tensorflow as tf
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.1.0

# %%
import numpy as np
import pandas as dp
import matplotlib.pyplot as plt

# %%
mnist = keras.datasets.fashion_mnist
type(mnist)
# Out:
# module

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# X_train: 60000 righe/esempi, dove ogni riga è una matrice 28x28 (pixel)
# y_train: 60000 label, una per ogni riga/esempio
X_train.shape, y_train.shape
# Out:
# ((60000, 28, 28), (60000,))

# %%
np.max(X_train), np.mean(X_train)
# Out:
# (255, 72.94035223214286)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ### Data Exploration

# %%
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
plt.figure()
print("Label: ", y_train[0])
plt.imshow(X_train[0])
plt.colorbar()
# Out:
# Label:  9

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
plt.figure()
print("Label: ", y_train[0])
plt.imshow(X_train[0])
plt.colorbar()
# Out:
# Label:  9

# %% [markdown]
# ### Build the model

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense

# %%
model = Sequential()
model.add(Flatten(input_shape= (28,28))) # transforma 28x28 in un vettore unico di 784 elementi
model.add(Dense(128, activation = 'relu'))
model.add(Dense(10, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Il livello `dense_2` ha 784*128+128 = 100480 parametri in quanto ogni
#
#     - Ognuno dei 784 neuroni di input è collegato a 128 neuroni di output (100352 archi) e dato che ogni arco ha un peso abbiamo 100352 pesi w
#     - Ogniuno dei 128 neuroni di arrivo ha un bias associato, quindi dobbiamo sommare a 100352 anche 128 bias

# %% [markdown]
# ### Model fit and evalutation
# - Loss function
# - Optimizer
# - Metrics

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# epochs corrisponde al numero di volte in cui la nostra rete vedi i dati (che vengono randomizzati)
# 0.2 % dei dati vengono utilizzati come validation set
history = model.fit(X_train, y_train, epochs = 10, batch_size = 50, validation_split = 0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 2s 52us/sample - loss: 0.5357 - accuracy: 0.8136 - val_loss: 0.4167 - val_accuracy: 0.8512
# Epoch 2/10
# 48000/48000 [==============================] - 2s 42us/sample - loss: 0.3928 - accuracy: 0.8603 - val_loss: 0.3747 - val_accuracy: 0.8714
# Epoch 3/10
# 48000/48000 [==============================] - 2s 32us/sample - loss: 0.3505 - accuracy: 0.8749 - val_loss: 0.3611 - val_accuracy: 0.8738
# Epoch 4/10
# 48000/48000 [==============================] - 2s 33us/sample - loss: 0.3235 - accuracy: 0.8830 - val_loss: 0.3583 - val_accuracy: 0.8717
# Epoch 5/10
# 48000/48000 [==============================] - 2s 36us/sample - loss: 0.3062 - accuracy: 0.8882 - val_loss: 0.3364 - val_accuracy: 0.8755
# Epoch 6/10
# 48000/48000 [==============================] - 2s 37us/sample - loss: 0.2901 - accuracy: 0.8931 - val_loss: 0.3553 - val_accuracy: 0.8739
# Epoch 7/10
# ...

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(test_acc)
# Out:
# 10000/10000 [==============================] - 0s 47us/sample - loss: 0.3501 - accuracy: 0.8771
# 0.8771

# %%
from sklearn.metrics import accuracy_score

# rispetto a model.predict, predict_classes restituisce direttamente la classe con il valore più alto
y_pred = model.predict_classes(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8771

# %%
pred = model.predict(X_test)
print(y_test[0])
print(pred[0])
print(np.argmax(pred[0]))
# Out:
# 9
# [1.1688724e-08 2.3182032e-09 2.5419866e-09 1.9054767e-09 6.8078103e-09
#  3.3436343e-04 3.6330457e-07 5.9861313e-03 1.3864761e-06 9.9367768e-01]
# 9

# %% [markdown]
# ### Plotting learning curve and confusion metrix

# %%
help(model)
# Out:
# Help on Sequential in module tensorflow.python.keras.engine.sequential object:
#
# class Sequential(tensorflow.python.keras.engine.training.Model)
#  |  Linear stack of layers.
#  |
#  |  Arguments:
#  |      layers: list of layers to add to the model.
#  |
#  |  Example:
#  |
#  |  ```python
#  |  # Optionally, the first layer can receive an `input_shape` argument:
#  |  model = Sequential()
#  |  model.add(Dense(32, input_shape=(500,)))
#  |  # Afterwards, we do automatic shape inference:
#  |  model.add(Dense(32))
#  |
#  |  # This is identical to the following:
#  |  model = Sequential()
#  |  model.add(Dense(32, input_dim=500))
#  |
#  |  # And to the following:
#  |  model = Sequential()
#  |  model.add(Dense(32, batch_input_shape=(None, 500)))
#  |
#  |  # Note that you can also omit the `input_shape` argument:
#  |  # In that case the model gets built the first time you call `fit` (or other
#  |  # training and evaluation methods).
#  |  model = Sequential()
# ...

# %%
history.history
# Out:
# {'loss': [0.5357288929323355,
#   0.39282261883684744,
#   0.3505359792849049,
#   0.32349878539486476,
#   0.30623998449494444,
#   0.29009923212385424,
#   0.2751109786797315,
#   0.2650642790443574,
#   0.2547223977356528,
#   0.24421008967328817],
#  'accuracy': [0.8135833,
#   0.86029166,
#   0.874875,
#   0.8830208,
#   0.8882083,
#   0.893125,
#   0.89858335,
#   0.9015,
#   0.9063125,
#   0.909375],
#  'val_loss': [0.4167194557686647,
#   0.37467175840089717,
#   0.3610844071333607,
#   0.35828582967321077,
#   0.33638818046698965,
#   0.3553458148924013,
#   0.34732676222920417,
#   0.3379989258013666,
#   0.3203997035510838,
#   0.3197622295158605],
#  'val_accuracy': [0.85125,
#   0.8714167,
#   0.87383336,
#   0.87175,
#   0.8755,
#   0.8739167,
#   0.87575,
#   0.8775833,
#   0.886,
#   0.8875833]}

# %%
import matplotlib.pyplot as plt

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %% [markdown]
# #### Plot confusion matrix

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
import matplotlib

# %%
font = {
    'family': 'Arial',
    # 'family': 'Times New Roman',
    # 'weight': 'normal',
    'size': 12
}
matplotlib.rc('font', **font)
mat = confusion_matrix(y_test, y_pred)
# show_normed = per mostrare le precisione di ogni cella
plot_confusion_matrix(conf_mat=mat, figsize=(10,10), class_names = class_names, show_normed=True)
# Out:
# (<Figure size 720x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x63bd12160>)

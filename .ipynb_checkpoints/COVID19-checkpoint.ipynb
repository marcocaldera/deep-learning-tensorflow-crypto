# %%
from pathlib import Path, PosixPath
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import math
import shutil

# %%
dirpath = os.path.join('COVID-19')
if os.path.exists(dirpath) and os.path.isdir(dirpath):
    shutil.rmtree(dirpath)

# %%
# !git clone https://github.com/pcm-dpc/COVID-19.git
# Out:
# Cloning into 'COVID-19'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 876 (delta 8), reused 16 (delta 6), pack-reused 842
# Receiving objects: 100% (876/876), 31.15 MiB | 7.56 MiB/s, done.
# Resolving deltas: 100% (577/577), done.

# %% [raw]
# main_folder_path = Path('./COVID-19/dati-regioni')
# label_list = np.array(os.listdir(path=main_folder_path))
# label_list

# %%
df = pd.read_csv('./COVID-19/dati-andamento-nazionale/dpc-covid19-ita-andamento-nazionale.csv')
print("Numero di esempi: ", len(df))
df.tail()
# Out:
# Numero di esempi:  26
#                    data stato  ricoverati_con_sintomi  terapia_intensiva  \
# 21  2020-03-16 17:00:00   ITA                   11025               1851
# 22  2020-03-17 17:00:00   ITA                   12894               2060
# 23  2020-03-18 17:00:00   ITA                   14363               2257
# 24  2020-03-19 17:00:00   ITA                   15757               2498
# 25  2020-03-20 17:00:00   ITA                   16020               2655
#
#     totale_ospedalizzati  isolamento_domiciliare  totale_attualmente_positivi  \
# 21                 12876                   10197                        23073
# 22                 14954                   11108                        26062
# 23                 16620                   12090                        28710
# 24                 18255                   14935                        33190
# 25                 18675                   19185                        37860
#
#     nuovi_attualmente_positivi  dimessi_guariti  deceduti  totale_casi  \
# 21                        2470             2749      2158        27980
# 22                        2989             2941      2503        31506
# 23                        2648             4025      2978        35713
# 24                        4480             4440      3405        41035
# 25                        4670             5129      4032        47021
#
#     tamponi
# 21   137962
# 22   148657
# 23   165541
# 24   182777
# 25   206886

# %%
df = pd.read_csv('./COVID-19/dati-regioni/dpc-covid19-ita-regioni.csv')
print("Numero di esempi: ", len(df))
df.tail()
# Out:
# Numero di esempi:  546
#                     data stato  codice_regione denominazione_regione  \
# 541  2020-03-20 17:00:00   ITA               9               Toscana
# 542  2020-03-20 17:00:00   ITA               4           P.A. Trento
# 543  2020-03-20 17:00:00   ITA              10                Umbria
# 544  2020-03-20 17:00:00   ITA               2         Valle d'Aosta
# 545  2020-03-20 17:00:00   ITA               5                Veneto
#
#            lat       long  ricoverati_con_sintomi  terapia_intensiva  \
# 541  43.769231  11.255889                     601                189
# 542  46.068935  11.121231                     198                 34
# 543  43.106758  12.388247                      75                 24
# 544  45.737503   7.320149                      54                  9
# 545  45.434905  12.338452                     843                236
#
#      totale_ospedalizzati  isolamento_domiciliare  \
# 541                   790                     923
# 542                   232                     368
# 543                    99                     285
# 544                    63                     194
# 545                  1079                    2598
#
#      totale_attualmente_positivi  nuovi_attualmente_positivi  dimessi_guariti  \
# 541                         1713                         291               33
# 542                          600                         109               29
# 543                          384                          56                4
# 544                          257                          48                0
# 545                         3677                         508              223
#
#      deceduti  totale_casi  tamponi
# 541        47         1793    10405
# 542        13          642     2656
# 543         7          395     2303
# 544         7          264      814
# 545       131         4031    49288

# %% [markdown]
# ### Numero di righe per regione

# %%
group = df.groupby('denominazione_regione')['denominazione_regione'].count()
group.head(20)
# Out:
# denominazione_regione
# Abruzzo                  26
# Basilicata               26
# Calabria                 26
# Campania                 26
# Emilia Romagna           26
# Friuli Venezia Giulia    26
# Lazio                    26
# Liguria                  26
# Lombardia                26
# Marche                   26
# Molise                   26
# P.A. Bolzano             26
# P.A. Trento              26
# Piemonte                 26
# Puglia                   26
# Sardegna                 26
# Sicilia                  26
# Toscana                  26
# Umbria                   26
# Valle d'Aosta            26
# Name: denominazione_regione, dtype: int64

# %% [markdown]
# ### Seleziona regione

# %%
regione = 'Piemonte'
#regione = 'Lombardia'

# %%
df_regione = df.loc[df['denominazione_regione'] == regione]

# %%
df_regione.tail()
# Out:
#                     data stato  codice_regione denominazione_regione  \
# 453  2020-03-16 17:00:00   ITA               1              Piemonte
# 474  2020-03-17 17:00:00   ITA               1              Piemonte
# 495  2020-03-18 17:00:00   ITA               1              Piemonte
# 516  2020-03-19 17:00:00   ITA               1              Piemonte
# 537  2020-03-20 17:00:00   ITA               1              Piemonte
#
#            lat      long  ricoverati_con_sintomi  terapia_intensiva  \
# 453  45.073274  7.680687                    1045                186
# 474  45.073274  7.680687                    1378                206
# 495  45.073274  7.680687                    1780                227
# 516  45.073274  7.680687                    2279                257
# 537  45.073274  7.680687                    1541                280
#
#      totale_ospedalizzati  isolamento_domiciliare  \
# 453                  1231                     174
# 474                  1584                     180
# 495                  2007                     180
# 516                  2536                     218
# 537                  1821                    1423
#
#      totale_attualmente_positivi  nuovi_attualmente_positivi  dimessi_guariti  \
# 453                         1405                         375                0
# 474                         1764                         359                0
# 495                         2187                         423                0
# 516                         2754                         567                3
# 537                         3244                         490                8
#
#      deceduti  totale_casi  tamponi
# 453       111         1516     5588
# 474       133         1897     6543
# 495       154         2341     7516
# 516       175         2932     8853
# 537       209         3461     9975

# %% [raw]
# df_regione = df_regione.set_index('data')
# df_regione.head(3)

# %% [markdown]
# ### Correlazione tamponi-casi

# %%
import matplotlib.pyplot as plt
from datetime import datetime
import matplotlib.dates as mdates

# %%
df_regione.plot(kind='scatter',x='tamponi',y='totale_casi',color='red')
plt.show()

# %% [markdown]
# ### Correlazione generale

# %%
# df_regione.corr()

# %%
# gca stands for 'get current axis'
ax = plt.gca()
    
df_regione.plot(kind='line',x='data',y='totale_casi',ax=ax, figsize=(15, 5), rot=0)
#df_regione.plot(kind='line',x='data',y='terapia_intensiva',ax=ax, figsize=(15, 5), rot=0)
df_regione.plot(kind='line',x='data',y='nuovi_attualmente_positivi',ax=ax, figsize=(15, 5), rot=0)

labels = [item.get_text() for item in ax.get_xticklabels()]
for i, label in enumerate(labels):
    try:
        labels[i] = label.split(' ')[0].split('-')[2]
    except IndexError:
        pass

ax.set_xticklabels(labels)
#ax.set_yticklabels(np.arange[1,1100,100])
plt.show()

# %% [markdown]
# ### Andamento generale

# %%
df_regione['incremento'] = df_regione['totale_casi'].pct_change() * 100
# Out:
# /opt/anaconda3/envs/ai/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_regione[['data','incremento']]
# Out:
#                     data  incremento
# 12   2020-02-24 18:00:00         NaN
# 33   2020-02-25 18:00:00    0.000000
# 54   2020-02-26 18:00:00    0.000000
# 75   2020-02-27 18:00:00  -33.333333
# 96   2020-02-28 18:00:00  450.000000
# 117  2020-02-29 17:00:00    0.000000
# 138  2020-03-01 17:00:00  345.454545
# 159  2020-03-02 18:00:00    4.081633
# 180  2020-03-03 18:00:00    9.803922
# 201  2020-03-04 17:00:00   46.428571
# 222  2020-03-05 17:00:00   31.707317
# 243  2020-03-06 17:00:00   32.407407
# 264  2020-03-07 18:00:00   44.755245
# 285  2020-03-08 18:00:00   73.913043
# 306  2020-03-09 18:00:00   -2.777778
# 327  2020-03-10 18:00:00   29.428571
# 348  2020-03-11 17:00:00   10.596026
# 369  2020-03-12 17:00:00   15.768463
# 390  2020-03-13 17:00:00   44.827586
# 411  2020-03-14 17:00:00    3.928571
# 432  2020-03-15 17:00:00   27.262314
# 453  2020-03-16 17:00:00   36.453645
# 474  2020-03-17 17:00:00   25.131926
# 495  2020-03-18 17:00:00   23.405377
# 516  2020-03-19 17:00:00   25.245622
# 537  2020-03-20 17:00:00   18.042292

# %%
ax = plt.gca()
df_regione.plot(kind='line',x='data',y='incremento',ax=ax, figsize=(15, 5))

labels = [item.get_text() for item in ax.get_xticklabels()]
for i, label in enumerate(labels):
    try:
        labels[i] = label.split(' ')[0].split('-')[2]
    except IndexError:
        pass

ax.set_xticklabels(labels)
plt.show()

# %%
df_regione.tail()
# Out:
#                     data stato  codice_regione denominazione_regione  \
# 453  2020-03-16 17:00:00   ITA               1              Piemonte
# 474  2020-03-17 17:00:00   ITA               1              Piemonte
# 495  2020-03-18 17:00:00   ITA               1              Piemonte
# 516  2020-03-19 17:00:00   ITA               1              Piemonte
# 537  2020-03-20 17:00:00   ITA               1              Piemonte
#
#            lat      long  ricoverati_con_sintomi  terapia_intensiva  \
# 453  45.073274  7.680687                    1045                186
# 474  45.073274  7.680687                    1378                206
# 495  45.073274  7.680687                    1780                227
# 516  45.073274  7.680687                    2279                257
# 537  45.073274  7.680687                    1541                280
#
#      totale_ospedalizzati  isolamento_domiciliare  \
# 453                  1231                     174
# 474                  1584                     180
# 495                  2007                     180
# 516                  2536                     218
# 537                  1821                    1423
#
#      totale_attualmente_positivi  nuovi_attualmente_positivi  dimessi_guariti  \
# 453                         1405                         375                0
# 474                         1764                         359                0
# 495                         2187                         423                0
# 516                         2754                         567                3
# 537                         3244                         490                8
#
#      deceduti  totale_casi  tamponi  incremento
# 453       111         1516     5588   36.453645
# 474       133         1897     6543   25.131926
# 495       154         2341     7516   23.405377
# 516       175         2932     8853   25.245622
# 537       209         3461     9975   18.042292
